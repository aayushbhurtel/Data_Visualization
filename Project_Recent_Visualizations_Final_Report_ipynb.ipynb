# %% [markdown]
# <a href="https://colab.research.google.com/github/aayushbhurtel/Data_Visualization/blob/main/Project_Recent_Visualizations_Final_Report_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Review Visualization
#
# ## Data visualization
#
# ## Aayush Bhurtel

# %% [markdown]
# ### I have selected the unemployment rate visualization in US for this recent visualization assignment.
#
# Here is a link to that interactive visualization.
#
# https://datawrapper.dwcdn.net/6AU3h/2/
#
#
# reference:
# https://www.cnbc.com/2021/08/06/unemployment-rate-falls-but-is-higher-for-black-and-hispanic-workers.html

# %% [markdown]
# ![Screenshot 2022-04-25 at 10-36-00 U.S. unemployment rates for Black Hispanic and white workers.png](data:image/png;base64,...)

# %% [markdown]
# this chart describes the recent unemployement rates on different races of people in united state. Back, Hispanic and White workers are classisified and graphed their unemployment rate.

# %% [markdown]
# Report:
