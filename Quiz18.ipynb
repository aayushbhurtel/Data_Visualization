# %% [markdown]
# <a href="https://colab.research.google.com/github/aayushbhurtel/Data_Visualization/blob/main/Quiz18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualization
# ## Aayush Bhurtel
# One Hot Encoding

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/nurfnick/Data_Viz/main/AB_NYC_2019.csv")
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# I am to convert neighbourhood_group and room_type into numberical data.
#
# First, let me identify the types in both columns.

# %%
n_group = sorted(df.neighbourhood_group.unique())
n_group
# Out:
# ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island']

# %%
roomType = sorted(df.room_type.unique())
roomType
# Out:
# ['Entire home/apt', 'Private room', 'Shared room']

# %% [markdown]
# Here, let me convert room_type into numerical data first using get_dummies function.

# %%
pd.get_dummies(df.room_type)
# Out:
#        Entire home/apt  Private room  Shared room
# 0                    0             1            0
# 1                    1             0            0
# 2                    0             1            0
# 3                    1             0            0
# 4                    1             0            0
# ...                ...           ...          ...
# 48890                0             1            0
# 48891                0             1            0
# 48892                1             0            0
# 48893                0             0            1
# 48894                0             1            0
#
# [48895 rows x 3 columns]

# %% [markdown]
# we can see from above result that there are three categories. when I apply get_dummies to these category, pandas will create a value of 1 if the category exist in that row and 0 if not.
#
# now lets add these into the dataframe.

# %%
df1 = pd.concat([df,pd.get_dummies(df.room_type)],axis = 1)

df1 = df1.drop('room_type', axis = 1)

df1
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# Now I am going to tranform neighbourhood_group using dictionary. first let me grab the categories in this column.

# %%
n_group = sorted(df.neighbourhood_group.unique())
n_group
# Out:
# ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island']

# %% [markdown]
# now lets build a dictionary and assign values to each of them.

# %%
neighbourhoodGroupDict = {}

for i in range(5):
  neighbourhoodGroupDict[n_group[i]] = i

neighbourhoodGroupDict
# Out:
# {'Bronx': 0, 'Brooklyn': 1, 'Manhattan': 2, 'Queens': 3, 'Staten Island': 4}

# %% [markdown]
# lets count the total numbers in each category

# %%
df.groupby('neighbourhood_group').neighbourhood.agg('count')
# Out:
# neighbourhood_group
# Bronx             1091
# Brooklyn         20104
# Manhattan        21661
# Queens            5666
# Staten Island      373
# Name: neighbourhood, dtype: int64

# %% [markdown]
# let apply dictionary with a map so that we can put it back into a dataFrame.

# %%
df.neighbourhood_group.map(neighbourhoodGroupDict)
# Out:
# 0        1
# 1        2
# 2        2
# 3        1
# 4        2
#         ..
# 48890    1
# 48891    1
# 48892    2
# 48893    2
# 48894    2
# Name: neighbourhood_group, Length: 48895, dtype: int64

# %% [markdown]
# finally putting it back into a df1 with room_type categorial values.

# %%
df1.neighbourhood_group = df.neighbourhood_group.map(neighbourhoodGroupDict)
df1.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name  neighbourhood_group neighbourhood  latitude  longitude  price  \
# 0         John                    1    Kensington  40.64749  -73.97237    149
# 1     Jennifer                    2       Midtown  40.75362  -73.98377    225
# 2    Elisabeth                    2        Harlem  40.80902  -73.94190    150
# 3  LisaRoxanne                    1  Clinton Hill  40.68514  -73.95976     89
# 4        Laura                    2   East Harlem  40.79851  -73.94399     80
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %% [markdown]
# done!
